# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
spark = SparkSession.builder \
    .appName("analytics") \
    .config("spark.sql.adaptive.enabled","true") \
    .getOrCreate()

spark

# %% [markdown]
# #### Different ways to read data using Spark

# %%
customers = spark.read.format("json").load("/Volumes/gizmobox/landing/operational_data/customers/")

# %%
display(customers)

# %%
df = spark.sql('select * from json.`/Volumes/gizmobox/landing/operational_data/customers/`')

# %%
display(df)

# %%
df = spark.table('gizmobox.bronze.v_addresses')
display(df)
