# %%
# %sql 
USE CATALOG gizmobox;

# %%
# %sql 
USE CATALOG gizmobox;
USE SCHEMA landing;
SELECT *
FROM binaryFile.`/Volumes/gizmobox/landing/operational_data/memeberships/*/*.png`

# %%
# %sql 
USE CATALOG gizmobox;
USE SCHEMA bronze;

CREATE VIEW IF NOT EXISTS v_memberships
AS
SELECT *
FROM binaryFile.`/Volumes/gizmobox/landing/operational_data/memeberships/*/*.png`

# %%
# %sql
select * from v_memberships;
