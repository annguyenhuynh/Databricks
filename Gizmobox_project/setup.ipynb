# %%
# %sql
show catalogs

# %%
# %sql
CREATE CATALOG IF NOT EXISTS gizmobox
COMMENT 'This is the catalog for Gizmobox Data Lakehouse'

# %%
# %sql
USE CATALOG gizmobox;

CREATE SCHEMA IF NOT EXISTS landing;

# %%
# %sql
USE CATALOG gizmobox;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
# %sql
show schemas

# %%
# %sql
USE CATALOG gizmobox;
USE SCHEMA landing;
    
CREATE VOLUME IF NOT EXISTS operational_data

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data

# %%
dbutils.fs.cp(
  "/Workspace/Users/nhuynh27@gmu.edu/Databricks/Gizmobox_project/data/addresses",
  "/Volumes/gizmobox/landing/operational_data/addresses/",
  recurse=True
)

# %%
dbutils.fs.cp(
    "/Workspace/Users/nhuynh27@gmu.edu/Databricks/Gizmobox_project/data/customers",
    "/Volumes/gizmobox/landing/operational_data/customers/",
    recurse=True
)

# %%
dbutils.fs.cp(
    "/Workspace/Users/nhuynh27@gmu.edu/Databricks/Gizmobox_project/data/memberships",
    "/Volumes/gizmobox/landing/operational_data/memeberships/",
    recurse=True
)

# %%
dbutils.fs.cp(
    "/Workspace/Users/nhuynh27@gmu.edu/Databricks/Gizmobox_project/data/orders",
    "/Volumes/gizmobox/landing/operational_data/orders/",
    recurse=True
)
